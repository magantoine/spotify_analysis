# %% [markdown]
# # Spotify data study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
import imblearn
import sklearn

import sys
sys.path.append("../helpers")
import ploter

from importlib import reload
reload(ploter)
# Out:
# <module 'ploter' from '../helpers\\ploter.py'>

# %% [markdown]
# ### 3 - Loading the data

# %%
BASE_PATH = "../my_spotify_data/StreamingHistory{}.json"

dfs = []

for i in range(5):
    dfs.append(pd.read_json(BASE_PATH.format(i)))
df = pd.concat(dfs)
df = df.reset_index(drop='True')

# %%
df.head()
# Out:
#             endTime            artistName                        trackName  \
# 0  2020-11-20 08:55        Rayland Baxter                      Yellow Eyes
# 1  2020-11-21 09:04             FloodCast  S06E04 - Deux Teufeurs Pas Purs
# 2  2020-11-21 12:53  Peter Bjorn and John                      Young Folks
# 3  2020-11-21 12:53                 alt-J                     Breezeblocks
# 4  2020-11-21 12:57                 Bibio                 lovers’ carvings
#
#    msPlayed
# 0    156074
# 1   1465471
# 2      4800
# 3      5290
# 4    238640

# %% [markdown]
# ### 2 - EDA
#
# understanding my data by spotify : https://support.spotify.com/us/article/understanding-my-data/
#
# msPlayed : number of milliseconds during which the music was played
#
# ##### a) Deduce the start time and overal runtime

# %%
## translate to date and timedelta
df["endTime"] = pd.to_datetime(df.endTime) 
df["msPlayedDate"] = df.msPlayed.apply(lambda listening_time : pd.Timedelta(listening_time, unit="ms"))

## deduce start time
df["startTime"] = df.endTime - df.msPlayedDate

# %%
df[["startTime", "endTime", "msPlayedDate"]]
# Out:
#                     startTime             endTime           msPlayedDate
# 0     2020-11-20 08:52:23.926 2020-11-20 08:55:00 0 days 00:02:36.074000
# 1     2020-11-21 08:39:34.529 2020-11-21 09:04:00 0 days 00:24:25.471000
# 2     2020-11-21 12:52:55.200 2020-11-21 12:53:00 0 days 00:00:04.800000
# 3     2020-11-21 12:52:54.710 2020-11-21 12:53:00 0 days 00:00:05.290000
# 4     2020-11-21 12:53:01.360 2020-11-21 12:57:00 0 days 00:03:58.640000
# ...                       ...                 ...                    ...
# 41280 2021-11-21 22:48:58.592 2021-11-21 22:49:00 0 days 00:00:01.408000
# 41281 2021-11-21 22:49:27.987 2021-11-21 22:53:00 0 days 00:03:32.013000
# 41282 2021-11-21 22:52:24.960 2021-11-21 22:57:00 0 days 00:04:35.040000
# 41283 2021-11-21 22:57:42.360 2021-11-21 23:01:00 0 days 00:03:17.640000
# 41284 2021-11-21 23:00:59.000 2021-11-21 23:03:00        0 days 00:02:01
#
# [41285 rows x 3 columns]

# %% [markdown]
# ##### c) Listening time study

# %%
df.msPlayed
# Out:
# 0         156074
# 1        1465471
# 2           4800
# 3           5290
# 4         238640
#           ...
# 41280       1408
# 41281     212013
# 41282     275040
# 41283     197640
# 41284     121000
# Name: msPlayed, Length: 41285, dtype: int64

# %%
f = plt.figure(figsize=(16, 5))
g = sns.histplot(data=df, x="msPlayed")
g.set_yscale("log")

# %% [markdown]
# They are some weird max values , let's have a look at this :

# %%
## 10 longest listening
longest = np.argsort(df.msPlayed)[-30:]

df.iloc[longest]
# Out:
#                   endTime                                artistName  \
    return artist in known_podcasters

known_podcasters =  ["FloodCast", "PARDON LE CINÉMA", "La Table Ovale", "Un Bon Moment avec Kyan KHOJANDI et NAVO", "We Love TFTC"]
df["known_podcast"] = df.artistName.apply(lambda artist : is_known_podcast(artist, known_podcasters))
df["title_len"] = df.trackName.apply(len)

# %%
def normalize(X, mean, std):
    return (X - mean)/std

# %%
## select a balanced dataset
true_entry = df[df.known_podcast].sample(n=80)
false_entry = df[~df.known_podcast].sample(n=200)

data = pd.concat([true_entry, false_entry])
X, y = data[["title_len", "msPlayed"]].to_numpy(), data["known_podcast"].to_numpy()
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.2)

mu = X_train.mean(axis=0)
sig = X_train.std(axis=0)

# %%
## have to normalize due to magnitude difference between both features
X_train = normalize(X_train, mu, sig)
X_test = normalize(X_test, mu, sig)

# %%
f = plt.figure(figsize=(15, 6))
colors = ["red" if x == 0 else "blue" for x in y_train]
plt.scatter(x=X_train[:,0], y=X_train[:,1], color=colors)

# %%
model = sklearn.svm.SVC(kernel='poly', C=0.1, degree=8, gamma=1.0, coef0=1.0).fit(X_train, y_train)

# %%
print(f"R square score for the model : {model.score(X_test, y_test)}") ## rather good R^2 value
# Out:
# R square score for the model : 0.8392857142857143

# %%
### small cross val
ds = range(1, 15)
gs = range(1, 8, 3)
rss = np.zeros((len(ds), len(gs)))
for i, d in enumerate(ds):
    for j, g in enumerate(gs):
        print((i, j))
        rss[i, j] = sklearn.svm.SVC(kernel='poly', C=0.1, degree=d, gamma=g, coef0=1.0).fit(X_train, y_train).score(X_test, y_test)
# Out:
# (0, 0)
# (0, 1)
# (0, 2)
# (1, 0)
# (1, 1)
# (1, 2)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)
# (4, 0)
# (4, 1)
# (4, 2)
# (5, 0)
# (5, 1)
# (5, 2)
# (6, 0)
# (6, 1)
# (6, 2)
# (7, 0)
# (7, 1)
# (7, 2)
# (8, 0)
# (8, 1)
# (8, 2)
# (9, 0)
# (9, 1)
# (9, 2)
# (10, 0)
# (10, 1)

# %%
model = sklearn.svm.SVC(kernel='poly', C=0.1, degree=2, gamma=3, coef0=1.0).fit(X_train, y_train)
print(f"R square score for the model : {model.score(X_test, y_test)}") ## rather good R^2 value
# Out:
# R square score for the model : 0.8392857142857143

# %%
ploter.plot(X_train, y_train, model)
# Out:
# ../helpers\ploter.py:38: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
X = normalize(df[["title_len", "msPlayed"]].to_numpy(), mu, sig)

df["music"] = ~model.predict(X)

# %%
df[~df.music].sample(n=50)
# Out:
#                   endTime                                         artistName  \
# 12040 2021-03-18 22:01:00                                     Nouvelle École
# 7313  2021-02-01 23:45:00                          Les Couilles sur la table
# 16191 2021-04-27 19:25:00                                         Crac Crac
# 10578 2021-03-09 10:23:00                                         Ben Névert
# 6562  2021-01-25 23:12:00                                          FloodCast
# 7329  2021-02-02 14:48:00           Un Bon Moment avec Kyan KHOJANDI et NAVO
# 29578 2021-08-13 16:23:00                                          FloodCast
# 1513  2020-12-05 10:50:00                                         On réécrit
# 362   0 days 00:25:47.354000 2020-11-25 15:10:12.646           True
# 36495 0 days 00:13:31.077000 2021-10-15 14:30:28.923          False
# 15308 0 days 00:23:14.048000 2021-04-18 07:55:45.952          False
#
#        title_len  music
# 12040         70  False
# 7313          27  False
# 16191         14  False
# 10578         53  False
# 6562          41  False
# 7329          42  False
# 29578         50  False
# 1513          27  False
# 40053         27  False
# 34216         52  False
# 21388         23  False
# 39550         29  False
# 9631          39  False
# 15583         29  False
# 14766         34  False
# 10862         28  False
# 9271          87  False
# 37500         41  False
# 12039         45  False
# 15400         49  False
# 11173         41  False
# 7538          34  False
# 25991         52  False
# 39223         52  False
# 32578         43  False
# 12205         40  False
# 6709          41  False
# 40017         68  False
# 9559          92  False
# 10325         63  False
# 28836         52  False
# 2568          54  False
# 16268         24  False
# 16630         24  False
# 15188         35  False
# 15307         17  False
# 12559         42  False
# 17622         25  False
# 2570          54  False
# 9761          27  False
# 36497         52  False
# 1080          68  False
# 27044         80  False
# 26728         82  False
# 110           31  False
# 10022         44  False
# 39845         29  False
# 362           31  False
# 36495         52  False
# 15308         17  False

# %%
df = df[df.music]

# %%
df.head()
# Out:
#               endTime            artistName         trackName  msPlayed  \
# 0 2020-11-20 08:55:00        Rayland Baxter       Yellow Eyes    156074
# 2 2020-11-21 12:53:00  Peter Bjorn and John       Young Folks      4800
# 3 2020-11-21 12:53:00                 alt-J      Breezeblocks      5290
# 4 2020-11-21 12:57:00                 Bibio  lovers’ carvings    238640
# 5 2020-11-21 13:02:00           Fleet Foxes           Mykonos    275306
#
#             msPlayedDate               startTime  known_podcast  title_len  \
# 0 0 days 00:02:36.074000 2020-11-20 08:52:23.926          False         11
# 2 0 days 00:00:04.800000 2020-11-21 12:52:55.200          False         11
# 3 0 days 00:00:05.290000 2020-11-21 12:52:54.710          False         12
# 4 0 days 00:03:58.640000 2020-11-21 12:53:01.360          False         16
# 5 0 days 00:04:35.306000 2020-11-21 12:57:24.694          False          7
#
#    music
# 0   True
# 2   True
# 3   True
# 4   True
# 5   True

# %%
f = plt.figure(figsize=(16, 5))
g = sns.histplot(data=df, x="msPlayed")
g.set_yscale("log");

# %%
stats = ploter.CIs(data=df, columns=["msPlayed"], funcs=[np.mean])
stats["msPlayed"] = stats.msPlayed.apply(lambda x : pd.Timedelta(x, unit='ms'))
stats
# Out:
#                                msPlayed
# mean_low      0 days 00:02:19.535689367
# mean_computed 0 days 00:02:20.626831654
# mean_high     0 days 00:02:21.801765541

# %% [markdown]
# ##### d) Unicity of entries

# %%
df.head()
# Out:
#               endTime            artistName         trackName  msPlayed  \
# 0 2020-11-20 08:55:00        Rayland Baxter       Yellow Eyes    156074
# 2 2020-11-21 12:53:00  Peter Bjorn and John       Young Folks      4800
# 3 2020-11-21 12:53:00                 alt-J      Breezeblocks      5290
# 4 2020-11-21 12:57:00                 Bibio  lovers’ carvings    238640
# 5 2020-11-21 13:02:00           Fleet Foxes           Mykonos    275306
#
#             msPlayedDate               startTime  known_podcast  title_len  \
# 0 0 days 00:02:36.074000 2020-11-20 08:52:23.926          False         11
# 2 0 days 00:00:04.800000 2020-11-21 12:52:55.200          False         11
# 3 0 days 00:00:05.290000 2020-11-21 12:52:54.710          False         12
# 4 0 days 00:03:58.640000 2020-11-21 12:53:01.360          False         16
# 5 0 days 00:04:35.306000 2020-11-21 12:57:24.694          False          7
#
#    music
# 0   True
# 2   True
# 3   True
# 4   True
# 5   True

# %%
print(f"Total : {len(df.index)}, number of unique tracks : {len(np.unique(df.trackName))}")
# Out:
# Total : 41189, number of unique tracks : 7202

# %%
counts = pd.DataFrame(df.groupby("trackName").apply(len)).reset_index(drop=False)
counts = counts.rename(columns={0:"counts"})
df = pd.merge(df, counts, on="trackName")
df = df.sort_values(by="startTime")

# %%
df.head()
# Out:
#                 endTime            artistName         trackName  msPlayed  \
# 0   2020-11-20 08:55:00        Rayland Baxter       Yellow Eyes    156074
# 136 2020-11-21 12:53:00                 alt-J      Breezeblocks      5290
# 77  2020-11-21 12:53:00  Peter Bjorn and John       Young Folks      4800
# 196 2020-11-21 12:57:00                 Bibio  lovers’ carvings    238640
# 211 2020-11-21 13:02:00           Fleet Foxes           Mykonos    275306
#
#               msPlayedDate               startTime  known_podcast  title_len  \
# 0   0 days 00:02:36.074000 2020-11-20 08:52:23.926          False         11
# 136 0 days 00:00:05.290000 2020-11-21 12:52:54.710          False         12
# 77  0 days 00:00:04.800000 2020-11-21 12:52:55.200          False         11
# 196 0 days 00:03:58.640000 2020-11-21 12:53:01.360          False         16
# 211 0 days 00:04:35.306000 2020-11-21 12:57:24.694          False          7
#
#      music  counts
# 0     True      77
# 136   True      60
# 77    True      59
# 196   True      15
# 211   True      52

# %%
f = plt.figure(figsize=(16, 5))
sns.histplot(data=df, x="counts");

# %% [markdown]
# Most listen tunes :

# %%
df.drop_duplicates("trackName").sort_values(by="counts").tail(n=10)
# Out:
#                   endTime     artistName                trackName  msPlayed  \
# 21661 2021-01-15 19:53:00  L'Impératrice         Sonate Pacifique    348944
# 6406  2020-11-27 11:07:00      The Voidz    Leave It In My Dreams    239441
# 5849  2020-11-26 16:05:00       Interpol        No I In Threesome    231533
# 17392 2021-01-02 09:05:00         Papooz       Ann Wants to Dance    210786
# 7306  2020-11-27 13:15:00    The Strokes  Under Cover of Darkness    235546
# 1628  2020-11-21 23:53:00    The Strokes       You Only Live Once       597
# 6599  2020-11-27 11:17:00   Broken Bells            The High Road    232200
# 355   2020-11-21 13:33:00    Real Estate                It's Real    168493
# 6898  2020-11-27 13:02:00       Interpol        Rest My Chemistry    301093
# 7138  2020-11-27 13:11:00      Metronomy                 The Look    277653
#
#                 msPlayedDate               startTime  known_podcast  \
# 21661 0 days 00:05:48.944000 2021-01-15 19:47:11.056          False
# 6406  0 days 00:03:59.441000 2020-11-27 11:03:00.559          False
# 5849  0 days 00:03:51.533000 2020-11-26 16:01:08.467          False
# 17392 0 days 00:03:30.786000 2021-01-02 09:01:29.214          False
# 7306  0 days 00:03:55.546000 2020-11-27 13:11:04.454          False
# 1628  0 days 00:00:00.597000 2020-11-21 23:52:59.403          False
# 6599  0 days 00:03:52.200000 2020-11-27 11:13:07.800          False
# 355   0 days 00:02:48.493000 2020-11-21 13:30:11.507          False
# 6898  0 days 00:05:01.093000 2020-11-27 12:56:58.907          False
# 7138  0 days 00:04:37.653000 2020-11-27 13:06:22.347          False
#
#        title_len  music  counts
# 21661         16   True     126
# 6406          21   True     126
# 5849          17   True     131
# 17392         18   True     132
# 7306          23   True     134
# 1628          18   True     147
# 6599          13   True     150
# 355            9   True     154
# 6898          17   True     158
# 7138           8   True     168

# %% [markdown]
# Let's see with artists : Are you a stan?

# %%
artistCounts = pd.DataFrame(df.groupby("artistName").apply(len)).reset_index(drop=False)
artistCounts = artistCounts.rename(columns={0:"counts"})

# %%
f = plt.figure(figsize=(16, 5))
g = sns.histplot(data=artistCounts, x="counts")
g.set_yscale("log")
g.set_xscale("log");
### lol it's a log log plot you're dangerous

# %%
f = plt.figure(figsize=(16, 5))
g = sns.histplot(data=artistCounts, x="counts")
g.set_yscale("log")

# %% [markdown]
# What are those max values :

# %%
artistCounts.sort_values(by="counts", ascending=False).head(n=15)
# Out:
#                  artistName  counts
# 2190            The Strokes    1872
# 114          Arctic Monkeys    1833
# 963                Interpol    1626
# 1685                Phoenix    1165
# 1756            Real Estate     826
# 1628                 Papooz     757
# 2124              The Kooks     744
# 1631                Parcels     631
# 1758  Red Hot Chili Peppers     614
# 75                  Alvvays     590
# 1421              Metronomy     522
# 1207          L'Impératrice     461
# 293            Broken Bells     446
# 2423                  alt-J     442
# 2220                 The xx     422

# %% [markdown]
# Examples of artists you've listened only once :

# %%
artistCounts[artistCounts.counts == 1].sample(n=10)
# Out:
#                    artistName  counts
# 935                 Hypnolove       1
# 2143        The Modern Lovers       1
# 2460                    shame       1
# 2117         The Juan Maclean       1
# 1379             Marlena Shaw       1
# 1920                Soft Cell       1
# 1769  Reverend And The Makers       1
# 2357         What After This?       1
# 381           Charming Horses       1
# 2252            Tony Anderson       1

# %%
artistCounts = artistCounts.rename(columns={'counts':"artist_count"})

# %%
df = df.merge(artistCounts, on="artistName")
df = df.rename(columns={"counts":"tune_count"})
# Out:
#                   endTime          artistName          trackName  msPlayed  \
# 0     2020-11-20 08:55:00      Rayland Baxter        Yellow Eyes    156074
# 1     2020-11-21 23:49:00      Rayland Baxter        Yellow Eyes    230786
# 2     2020-11-23 20:04:00      Rayland Baxter        Yellow Eyes    230786
# 3     2020-11-26 08:54:00      Rayland Baxter        Yellow Eyes    230786
# 4     2020-11-26 10:42:00      Rayland Baxter        Yellow Eyes    230786
# ...                   ...                 ...                ...       ...
# 41184 2021-11-19 16:21:00  Ancient Astronauts     I Came Running     15557
# 41185 2021-11-19 17:11:00        Damon Albarn  The Selfish Giant     55810
# 41186 2021-11-19 17:16:00        Damon Albarn  The Selfish Giant     53647
# 41187 2021-11-19 17:47:00    John Vincent III        Next to You    256520
# 41188 2021-11-21 16:25:00      Perfume Genius              Sides      1536
#
#                 msPlayedDate               startTime  known_podcast  \
# 0     0 days 00:02:36.074000 2020-11-20 08:52:23.926          False
# 1     0 days 00:03:50.786000 2020-11-21 23:45:09.214          False
# 2     0 days 00:03:50.786000 2020-11-23 20:00:09.214          False
# 3     0 days 00:03:50.786000 2020-11-26 08:50:09.214          False
# 4     0 days 00:03:50.786000 2020-11-26 10:38:09.214          False
# ...                      ...                     ...            ...
# 41184 0 days 00:00:15.557000 2021-11-19 16:20:44.443          False
# 41185 0 days 00:00:55.810000 2021-11-19 17:10:04.190          False
# 41186 0 days 00:00:53.647000 2021-11-19 17:15:06.353          False
# 41187 0 days 00:04:16.520000 2021-11-19 17:42:43.480          False
# 41188 0 days 00:00:01.536000 2021-11-21 16:24:58.464          False
#
#        title_len  music  tune_count  artist_count
# 0             11   True          77           136
# 1             11   True          77           136
# 2             11   True          77           136
# 3             11   True          77           136
# 4             11   True          77           136
# ...          ...    ...         ...           ...
# 41184         14   True           1             1
# 41185         17   True           2             2
# 41186         17   True           2             2
# 41187         11   True           1             1
# 41188          5   True           1             1
#
# [41189 rows x 11 columns]

# %%
df = df.sort_values(by="startTime")

# %%
df.head()
# Out:
#                 endTime            artistName         trackName  msPlayed  \
# 0   2020-11-20 08:55:00        Rayland Baxter       Yellow Eyes    156074
# 136 2020-11-21 12:53:00                 alt-J      Breezeblocks      5290
# 578 2020-11-21 12:53:00  Peter Bjorn and John       Young Folks      4800
# 648 2020-11-21 12:57:00                 Bibio  lovers’ carvings    238640
# 666 2020-11-21 13:02:00           Fleet Foxes           Mykonos    275306
#
#               msPlayedDate               startTime  known_podcast  title_len  \
# 0   0 days 00:02:36.074000 2020-11-20 08:52:23.926          False         11
# 136 0 days 00:00:05.290000 2020-11-21 12:52:54.710          False         12
# 578 0 days 00:00:04.800000 2020-11-21 12:52:55.200          False         11
# 648 0 days 00:03:58.640000 2020-11-21 12:53:01.360          False         16
# 666 0 days 00:04:35.306000 2020-11-21 12:57:24.694          False          7
#
#      music  tune_count  artist_count
# 0     True          77           136
# 136   True          60           442
# 578   True          59            70
# 648   True          15            18
# 666   True          52            60

# %% [markdown]
# Correlation Artist count/ track count ?

# %%
f = plt.figure(figsize=(13, 7))
g = sns.scatterplot(data=df.drop_duplicates("trackName"), x="artist_count", y="tune_count")
g.set_yscale("log")
g.set_xscale("log");

# %% [markdown]
# A typical day :

# %%
def get_season(date):
    month = date.month
    day = date.day
    if(month == 1 or month == 2 or (month == 12 and day > 20) or (month == 3 and day < 20)):
        return "Winter"
    elif ((month == 3 and day > 20) or (month == 4) or (month == 5) or (month == 6 and day < 20)):
        return "Spring"
    elif ((month == 6 and day > 20) or (month == 7) or (month == 8) or (month == 9 and day < 20)):
        return "Summer"
    else :
          return "Fall"

# %%
df["daytime"] = df.startTime.apply(lambda x : datetime(year=2021, month=1, day=1, hour=x.hour, minute=x.minute, second=x.second))
df["season"] = df.startTime.apply(get_season)

# %%
f, a = plt.subplots(figsize=(14, 5))
sns.kdeplot(data=df, x="daytime", hue="season");

# %%
f = plt.figure(figsize=(15, 5))
sns.histplot(data=df, x="startTime", binwidth=2);
